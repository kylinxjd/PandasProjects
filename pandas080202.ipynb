# %%
import pandas as pd
data = pd.read_csv('job.csv', encoding='gbk')

# %%
data
# Out:
#       city                company           company_number company_size  \
# 0       杭州         北京建设数字科技股份有限公司              CZ000325840     100-499人
# 1       杭州         杭州对点人力资源管理有限公司              CZ414409920     100-499人
# 2       杭州           杭州皮森教育科技有限公司              CZ393123780       20-99人
# 3   杭州-余杭区               圆通速递有限公司              CZ138773160     10000人以上
# 4       杭州             杭州数美科技有限公司              CZ504452280     100-499人
# 5    杭州-下沙         杭州沃镭智能科技股份有限公司              CZ346054610     100-499人
# 6       杭州           杭州金时资产管理有限公司              CZ573260080       20-99人
# 7   杭州-江干区         视联动力信息技术股份有限公司              CZ397785110   1000-9999人
# 8   杭州-江干区         视联动力信息技术股份有限公司              CZ397785110   1000-9999人
# 9   杭州-江干区         视联动力信息技术股份有限公司              CZ397785110   1000-9999人
# 10  杭州-江干区         视联动力信息技术股份有限公司              CZ397785110   1000-9999人
# 11  杭州-拱墅区         京东数字科技控股有限公司    CZ192921310D00112072216   1000-9999人
# ...

# %%
data.loc[0:10,['company', 'company_type', 'company_size', 'jobName', 'salary']]
# Out:
#            company company_type company_size                jobName     salary
# 0   北京建设数字科技股份有限公司           民营     100-499人           asp.net开发工程师     6K-12K
# 1   杭州对点人力资源管理有限公司           民营     100-499人               python开发    10K-15K
# 2     杭州皮森教育科技有限公司           民营       20-99人          python赴日开发工程师    20K-30K
# 3         圆通速递有限公司         上市公司     10000人以上          python高级开发工程师    15K-20K
# 4       杭州数美科技有限公司           民营     100-499人              python工程师  12.5K-25K
# 5   杭州沃镭智能科技股份有限公司           民营     100-499人          软件工程师（Python）     7K-14K
# 6     杭州金时资产管理有限公司           民营       20-99人        C++/Python开发工程师    13K-26K
# 7   视联动力信息技术股份有限公司           民营   1000-9999人       python开发(J10431)    10K-15K
# 8   视联动力信息技术股份有限公司           民营   1000-9999人             杭州Python开发     8K-15K
# 9   视联动力信息技术股份有限公司           民营   1000-9999人               Python开发     6K-10K
# 10  视联动力信息技术股份有限公司           民营   1000-9999人  Python开发(杭州! 杭州! 杭州!)     8K-10K

# %%
d = data.loc[0:10,['company', 'company_type', 'company_size', 'jobName', 'salary']]
d[d['company_type']=='民营']
# Out:
#            company company_type company_size                jobName     salary
# 0   北京建设数字科技股份有限公司           民营     100-499人           asp.net开发工程师     6K-12K
# 1   杭州对点人力资源管理有限公司           民营     100-499人               python开发    10K-15K
# 2     杭州皮森教育科技有限公司           民营       20-99人          python赴日开发工程师    20K-30K
# 4       杭州数美科技有限公司           民营     100-499人              python工程师  12.5K-25K
# 5   杭州沃镭智能科技股份有限公司           民营     100-499人          软件工程师（Python）     7K-14K
# 6     杭州金时资产管理有限公司           民营       20-99人        C++/Python开发工程师    13K-26K
# 7   视联动力信息技术股份有限公司           民营   1000-9999人       python开发(J10431)    10K-15K
# 8   视联动力信息技术股份有限公司           民营   1000-9999人             杭州Python开发     8K-15K
# 9   视联动力信息技术股份有限公司           民营   1000-9999人               Python开发     6K-10K
# 10  视联动力信息技术股份有限公司           民营   1000-9999人  Python开发(杭州! 杭州! 杭州!)     8K-10K

# %%
d[d['company_size']=='100-499人']
# Out:
#           company company_type company_size        jobName     salary
# 0  北京建设数字科技股份有限公司           民营     100-499人   asp.net开发工程师     6K-12K
# 1  杭州对点人力资源管理有限公司           民营     100-499人       python开发    10K-15K
# 4      杭州数美科技有限公司           民营     100-499人      python工程师  12.5K-25K
# 5  杭州沃镭智能科技股份有限公司           民营     100-499人  软件工程师（Python）     7K-14K

# %%
d = d = data.loc[0:10,['company', 'company_type', 'company_size', 'jobName', 'salary', 'updateDate']]

# %%
d
# Out:
#            company company_type company_size                jobName  \
# 0   北京建设数字科技股份有限公司           民营     100-499人           asp.net开发工程师
# 1   杭州对点人力资源管理有限公司           民营     100-499人               python开发
# 2     杭州皮森教育科技有限公司           民营       20-99人          python赴日开发工程师
# 3         圆通速递有限公司         上市公司     10000人以上          python高级开发工程师
# 4       杭州数美科技有限公司           民营     100-499人              python工程师
# 5   杭州沃镭智能科技股份有限公司           民营     100-499人          软件工程师（Python）
# 6     杭州金时资产管理有限公司           民营       20-99人        C++/Python开发工程师
# 7   视联动力信息技术股份有限公司           民营   1000-9999人       python开发(J10431)
# 8   视联动力信息技术股份有限公司           民营   1000-9999人             杭州Python开发
# 9   视联动力信息技术股份有限公司           民营   1000-9999人               Python开发
# 10  视联动力信息技术股份有限公司           民营   1000-9999人  Python开发(杭州! 杭州! 杭州!)
#
#        salary           updateDate
# 0      6K-12K  2019-07-11 08:38:16
# 1     10K-15K  2019-07-16 09:40:24
# 2     20K-30K  2019-07-16 10:58:01
# ...

# %%
d[d['updateDate']>'2019-07-10 23:38:16']
# Out:
#           company company_type company_size          jobName     salary  \
# 0  北京建设数字科技股份有限公司           民营     100-499人     asp.net开发工程师     6K-12K
# 1  杭州对点人力资源管理有限公司           民营     100-499人         python开发    10K-15K
# 2    杭州皮森教育科技有限公司           民营       20-99人    python赴日开发工程师    20K-30K
# 3        圆通速递有限公司         上市公司     10000人以上    python高级开发工程师    15K-20K
# 4      杭州数美科技有限公司           民营     100-499人        python工程师  12.5K-25K
# 5  杭州沃镭智能科技股份有限公司           民营     100-499人    软件工程师（Python）     7K-14K
# 6    杭州金时资产管理有限公司           民营       20-99人  C++/Python开发工程师    13K-26K
#
#             updateDate
# 0  2019-07-11 08:38:16
# 1  2019-07-16 09:40:24
# 2  2019-07-16 10:58:01
# 3  2019-07-16 10:59:39
# 4  2019-07-16 10:46:02
# 5  2019-07-16 08:47:04
# 6  2019-07-16 08:52:07

# %%
d[(d['updateDate']>'2019-07-10 23:38:16')  & (d['updateDate']<'2019-07-16 10:38:16')]
# Out:
#           company company_type company_size          jobName   salary  \
# 0  北京建设数字科技股份有限公司           民营     100-499人     asp.net开发工程师   6K-12K
# 1  杭州对点人力资源管理有限公司           民营     100-499人         python开发  10K-15K
# 5  杭州沃镭智能科技股份有限公司           民营     100-499人    软件工程师（Python）   7K-14K
# 6    杭州金时资产管理有限公司           民营       20-99人  C++/Python开发工程师  13K-26K
#
#             updateDate
# 0  2019-07-11 08:38:16
# 1  2019-07-16 09:40:24
# 5  2019-07-16 08:47:04
# 6  2019-07-16 08:52:07

# %%
t = pd.read_csv('test.csv')

# %%
t
# Out:
#    a a.1 a.2 a.3
# 0  b   a   a   a
# 1  a   a   a   a
# 2  b   a   a   a
# 3  a   a   a   a
# 4  b   a   a   a

# %% [markdown]
# ### 时间序列

# %%
date = pd.date_range('20190722', periods=6)

# %%
date
# Out:
# DatetimeIndex(['2019-07-22', '2019-07-23', '2019-07-24', '2019-07-25',
#                '2019-07-26', '2019-07-27'],
#               dtype='datetime64[ns]', freq='D')

# %%
import numpy as np
df = pd.DataFrame(np.random.rand(6, 4), index=date, columns=list('asdf'))
df
# Out:
#                    a         s         d         f
# 2019-07-22  0.290372  0.932896  0.040957  0.642782
# 2019-07-23  0.773694  0.287315  0.515688  0.712661
# 2019-07-24  0.280210  0.215815  0.933033  0.636359
# 2019-07-25  0.380468  0.561182  0.223541  0.901107
# 2019-07-26  0.377221  0.524790  0.912443  0.768739
# 2019-07-27  0.809510  0.783084  0.285113  0.892228

# %%
d
# Out:
#            company company_type company_size                jobName  \
# 0   北京建设数字科技股份有限公司           民营     100-499人           asp.net开发工程师
# 1   杭州对点人力资源管理有限公司           民营     100-499人               python开发
# 2     杭州皮森教育科技有限公司           民营       20-99人          python赴日开发工程师
# 3         圆通速递有限公司         上市公司     10000人以上          python高级开发工程师
# 4       杭州数美科技有限公司           民营     100-499人              python工程师
# 5   杭州沃镭智能科技股份有限公司           民营     100-499人          软件工程师（Python）
# 6     杭州金时资产管理有限公司           民营       20-99人        C++/Python开发工程师
# 7   视联动力信息技术股份有限公司           民营   1000-9999人       python开发(J10431)
# 8   视联动力信息技术股份有限公司           民营   1000-9999人             杭州Python开发
# 9   视联动力信息技术股份有限公司           民营   1000-9999人               Python开发
# 10  视联动力信息技术股份有限公司           民营   1000-9999人  Python开发(杭州! 杭州! 杭州!)
#
#        salary           updateDate
# 0      6K-12K  2019-07-11 08:38:16
# 1     10K-15K  2019-07-16 09:40:24
# 2     20K-30K  2019-07-16 10:58:01
# ...

# %%
d.head()
# Out:
#           company company_type company_size        jobName     salary  \
# 0  北京建设数字科技股份有限公司           民营     100-499人   asp.net开发工程师     6K-12K
# 1  杭州对点人力资源管理有限公司           民营     100-499人       python开发    10K-15K
# 2    杭州皮森教育科技有限公司           民营       20-99人  python赴日开发工程师    20K-30K
# 3        圆通速递有限公司         上市公司     10000人以上  python高级开发工程师    15K-20K
# 4      杭州数美科技有限公司           民营     100-499人      python工程师  12.5K-25K
#
#             updateDate
# 0  2019-07-11 08:38:16
# 1  2019-07-16 09:40:24
# 2  2019-07-16 10:58:01
# 3  2019-07-16 10:59:39
# 4  2019-07-16 10:46:02

# %%
d.head(2)
# Out:
#           company company_type company_size       jobName   salary  \
# 0  北京建设数字科技股份有限公司           民营     100-499人  asp.net开发工程师   6K-12K
# 1  杭州对点人力资源管理有限公司           民营     100-499人      python开发  10K-15K
#
#             updateDate
# 0  2019-07-11 08:38:16
# 1  2019-07-16 09:40:24

# %%
d.tail()
# Out:
#            company company_type company_size                jobName   salary  \
# 6     杭州金时资产管理有限公司           民营       20-99人        C++/Python开发工程师  13K-26K
# 7   视联动力信息技术股份有限公司           民营   1000-9999人       python开发(J10431)  10K-15K
# 8   视联动力信息技术股份有限公司           民营   1000-9999人             杭州Python开发   8K-15K
# 9   视联动力信息技术股份有限公司           民营   1000-9999人               Python开发   6K-10K
# 10  视联动力信息技术股份有限公司           民营   1000-9999人  Python开发(杭州! 杭州! 杭州!)   8K-10K
#
#              updateDate
# 6   2019-07-16 08:52:07
# 7   2019-07-04 11:53:47
# 8   2019-07-10 11:02:45
# 9   2019-07-10 11:02:46
# 10  2019-07-10 11:02:46

# %%
d.tail(3)
# Out:
#            company company_type company_size                jobName  salary  \
# 8   视联动力信息技术股份有限公司           民营   1000-9999人             杭州Python开发  8K-15K
# 9   视联动力信息技术股份有限公司           民营   1000-9999人               Python开发  6K-10K
# 10  视联动力信息技术股份有限公司           民营   1000-9999人  Python开发(杭州! 杭州! 杭州!)  8K-10K
#
#              updateDate
# 8   2019-07-10 11:02:45
# 9   2019-07-10 11:02:46
# 10  2019-07-10 11:02:46

# %%
df
# Out:
#                    a         s         d         f
# 2019-07-22  0.290372  0.932896  0.040957  0.642782
# 2019-07-23  0.773694  0.287315  0.515688  0.712661
# 2019-07-24  0.280210  0.215815  0.933033  0.636359
# 2019-07-25  0.380468  0.561182  0.223541  0.901107
# 2019-07-26  0.377221  0.524790  0.912443  0.768739
# 2019-07-27  0.809510  0.783084  0.285113  0.892228

# %%
df.index
# Out:
# DatetimeIndex(['2019-07-22', '2019-07-23', '2019-07-24', '2019-07-25',
#                '2019-07-26', '2019-07-27'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['a', 's', 'd', 'f'], dtype='object')

# %%
df.values
# Out:
# array([[0.29037241, 0.93289563, 0.04095732, 0.64278202],
#        [0.77369384, 0.28731458, 0.51568784, 0.7126608 ],
#        [0.28021   , 0.21581455, 0.93303328, 0.63635864],
#        [0.38046791, 0.56118173, 0.22354142, 0.90110704],
#        [0.37722127, 0.5247904 , 0.91244303, 0.7687387 ],
#        [0.80950969, 0.78308365, 0.28511313, 0.89222772]])

# %%
mov = pd.read_excel('豆瓣电影数据.xlsx', index_col=0)
df = mov.head(20)

# %%
df
# Out:
#                                        名字      投票人数              类型    产地  \
# 0                                  肖申克的救赎  692795.0           剧情/犯罪    美国
# 1                                    控方证人   42995.0        剧情/悬疑/犯罪    美国
# 2                                   美丽人生   327855.0        剧情/喜剧/爱情   意大利
# 3                                    阿甘正传  580897.0           剧情/爱情    美国
# 4                                    霸王别姬  478523.0        剧情/爱情/同性  中国大陆
# 5                                  泰坦尼克号   157074.0        剧情/爱情/灾难    美国
# 6                                  辛德勒的名单  306904.0        剧情/历史/战争    美国
# 7   新世纪福音战士剧场版：Air/真心为你 新世紀エヴァンゲリオン劇場版 Ai   24355.0  剧情/动作/科幻/动画/奇幻    日本
# 8          银魂完结篇：直到永远的万事屋 劇場版 銀魂 完結篇 万事屋よ   21513.0           剧情/动画    日本
# 9                                这个杀手不太冷   662552.0        剧情/动作/犯罪    法国
# 10                                  灿烂人生    16807.0        剧情/爱情/家庭   意大利
# 11                                  疯狂动物城  284652.0     喜剧/动作/动画/冒险    美国
# ...

# %%
arr = np.random.randint(0, 100, (5, 5))
df = pd.DataFrame(arr, 
                   index = list('ABCDE'),
                   columns=list('abcde'))
df
# Out:
#     a   b   c   d   e
# A  78  61  88  39  80
# B  50  76  82  78  30
# C  61  13  70  22  90
# D  88  55  76  59  47
# E  85  20  91   6  89

# %%
df.index
# Out:
# Index(['A', 'B', 'C', 'D', 'E'], dtype='object')

# %%
df.columns
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
df.dtypes
# Out:
# a    int32
# b    int32
# c    int32
# d    int32
# e    int32
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, A to E
# Data columns (total 5 columns):
# a    5 non-null int32
# b    5 non-null int32
# c    5 non-null int32
# d    5 non-null int32
# e    5 non-null int32
# dtypes: int32(5)
# memory usage: 140.0+ bytes

# %%
df['a']
# Out:
# A    78
# B    50
# C    61
# D    88
# E    85
# Name: a, dtype: int32

# %%
df['A':'A']
# Out:
#     a   b   c   d   e
# A  78  61  88  39  80

# %%
df
# Out:
#     a   b   c   d   e
# A  78  61  88  39  80
# B  50  76  82  78  30
# C  61  13  70  22  90
# D  88  55  76  59  47
# E  85  20  91   6  89

# %%
df.loc[:,'a':'c']
# Out:
#     a   b   c
# A  78  61  88
# B  50  76  82
# C  61  13  70
# D  88  55  76
# E  85  20  91

# %%
df.loc[:,'a']
# Out:
# A    78
# B    50
# C    61
# D    88
# E    85
# Name: a, dtype: int32

# %%
df.loc['A',:]
# Out:
# a    78
# b    61
# c    88
# d    39
# e    80
# Name: A, dtype: int32

# %%
df.loc[['A','C'],:]
# Out:
#     a   b   c   d   e
# A  78  61  88  39  80
# C  61  13  70  22  90

# %%
df.loc['A':'D',:]
# Out:
#     a   b   c   d   e
# A  78  61  88  39  80
# B  50  76  82  78  30
# C  61  13  70  22  90
# D  88  55  76  59  47

# %%
# 第一行的第2-4列
df.loc[['A'],'b':'d']
# Out:
#     b   c   d
# A  61  88  39

# %%
# 第1-3行,第2-4列
df.loc['A':'C','b':'d']
# Out:
#     b   c   d
# A  61  88  39
# B  76  82  78
# C  13  70  22

# %%
# 0-3行
df.iloc[:3,:]
# Out:
#     a   b   c   d   e
# A  78  61  88  39  80
# B  50  76  82  78  30
# C  61  13  70  22  90
# D  88  55  76  59  47

# %%
# 1，3行
df.iloc[[0,2],:]
# Out:
#     a   b   c   d   e
# A  78  61  88  39  80
# C  61  13  70  22  90

# %%
# 1-3行，2-4列
df.iloc[0:3,1:4]
# Out:
#     b   c   d
# A  61  88  39
# B  76  82  78
# C  13  70  22

# %%
mov = pd.read_excel('豆瓣电影数据.xlsx', index_col=0)
df = mov.head(20)

# %%
df
# Out:
#                                        名字      投票人数              类型    产地  \
# 0                                  肖申克的救赎  692795.0           剧情/犯罪    美国
# 1                                    控方证人   42995.0        剧情/悬疑/犯罪    美国
# 2                                   美丽人生   327855.0        剧情/喜剧/爱情   意大利
# 3                                    阿甘正传  580897.0           剧情/爱情    美国
# 4                                    霸王别姬  478523.0        剧情/爱情/同性  中国大陆
# 5                                  泰坦尼克号   157074.0        剧情/爱情/灾难    美国
# 6                                  辛德勒的名单  306904.0        剧情/历史/战争    美国
# 7   新世纪福音战士剧场版：Air/真心为你 新世紀エヴァンゲリオン劇場版 Ai   24355.0  剧情/动作/科幻/动画/奇幻    日本
# 8          银魂完结篇：直到永远的万事屋 劇場版 銀魂 完結篇 万事屋よ   21513.0           剧情/动画    日本
# 9                                这个杀手不太冷   662552.0        剧情/动作/犯罪    法国
# 10                                  灿烂人生    16807.0        剧情/爱情/家庭   意大利
# 11                                  疯狂动物城  284652.0     喜剧/动作/动画/冒险    美国
# ...

# %%
df = df.head(5)

# %%
df
# Out:
#        名字      投票人数        类型    产地                 上映时间   时长    年代   评分  \
# 0  肖申克的救赎  692795.0     剧情/犯罪    美国  1994-09-10 00:00:00  142  1994  9.6
# 1    控方证人   42995.0  剧情/悬疑/犯罪    美国  1957-12-17 00:00:00  116  1957  9.5
# 2   美丽人生   327855.0  剧情/喜剧/爱情   意大利  1997-12-20 00:00:00  116  1997  9.5
# 3    阿甘正传  580897.0     剧情/爱情    美国  1994-06-23 00:00:00  142  1994  9.4
# 4    霸王别姬  478523.0  剧情/爱情/同性  中国大陆  1993-01-01 00:00:00  171  1993  9.4
#
#      首映地点
# 0  多伦多电影节
# 1      美国
# 2     意大利
# 3   洛杉矶首映
# 4      香港

# %%
dic = {
    '名字':'复仇者联盟3',
    '投票人数':4565142,
    '类型':'剧情/科幻',
    '产地':'美国',
    '上映时间':'1994-09-10 10:00:00',
    '时长':154,
    '年代':1996,
    '评分':9.5,
    '首映地点':'美国'
}
s = pd.Series(dic)
s.name = 39999

# %%
s
# Out:
# 名字                   复仇者联盟3
# 投票人数                4565142
# 类型                    剧情/科幻
# 产地                       美国
# 上映时间    1994-09-10 10:00:00
# 时长                      154
# 年代                     1996
# 评分                      9.5
# 首映地点                     美国
# Name: 39999, dtype: object

# %%
cd = df.append(s)

# %%
cd.index
# Out:
# Int64Index([0, 1, 2, 3, 4, 39999], dtype='int64')

# %%
cd
# Out:
#            名字       投票人数        类型    产地                 上映时间   时长    年代   评分  \
# 0      肖申克的救赎   692795.0     剧情/犯罪    美国  1994-09-10 00:00:00  142  1994  9.6
# 1        控方证人    42995.0  剧情/悬疑/犯罪    美国  1957-12-17 00:00:00  116  1957  9.5
# 2       美丽人生    327855.0  剧情/喜剧/爱情   意大利  1997-12-20 00:00:00  116  1997  9.5
# 3        阿甘正传   580897.0     剧情/爱情    美国  1994-06-23 00:00:00  142  1994  9.4
# 4        霸王别姬   478523.0  剧情/爱情/同性  中国大陆  1993-01-01 00:00:00  171  1993  9.4
# 39999  复仇者联盟3  4565142.0     剧情/科幻    美国  1994-09-10 10:00:00  154  1996  9.5
#
#          首映地点
# 0      多伦多电影节
# 1          美国
# 2         意大利
# 3       洛杉矶首映
# 4          香港
# 39999      美国

# %%
# 删除行
cd.drop([39999])
# Out:
#        名字      投票人数        类型    产地                 上映时间   时长    年代   评分  \
# 0  肖申克的救赎  692795.0     剧情/犯罪    美国  1994-09-10 00:00:00  142  1994  9.6
# 1    控方证人   42995.0  剧情/悬疑/犯罪    美国  1957-12-17 00:00:00  116  1957  9.5
# 2   美丽人生   327855.0  剧情/喜剧/爱情   意大利  1997-12-20 00:00:00  116  1997  9.5
# 3    阿甘正传  580897.0     剧情/爱情    美国  1994-06-23 00:00:00  142  1994  9.4
# 4    霸王别姬  478523.0  剧情/爱情/同性  中国大陆  1993-01-01 00:00:00  171  1993  9.4
#
#      首映地点
# 0  多伦多电影节
# 1      美国
# 2     意大利
# 3   洛杉矶首映
# 4      香港

# %%
df
# Out:
#        名字      投票人数        类型    产地                 上映时间   时长    年代   评分  \
# 0  肖申克的救赎  692795.0     剧情/犯罪    美国  1994-09-10 00:00:00  142  1994  9.6
# 1    控方证人   42995.0  剧情/悬疑/犯罪    美国  1957-12-17 00:00:00  116  1957  9.5
# 2   美丽人生   327855.0  剧情/喜剧/爱情   意大利  1997-12-20 00:00:00  116  1997  9.5
# 3    阿甘正传  580897.0     剧情/爱情    美国  1994-06-23 00:00:00  142  1994  9.4
# 4    霸王别姬  478523.0  剧情/爱情/同性  中国大陆  1993-01-01 00:00:00  171  1993  9.4
#
#      首映地点  序号
# 0  多伦多电影节   1
# 1      美国   2
# 2     意大利   3
# 3   洛杉矶首映   4
# 4      香港   5

# %%
len(df)
# Out:
# 5

# %%
# 添加列
df.loc[:,['序号hh']] = range(len(df))

# %%
df
# Out:
#        名字      投票人数        类型    产地                 上映时间   时长    年代   评分  \
# 0  肖申克的救赎  692795.0     剧情/犯罪    美国  1994-09-10 00:00:00  142  1994  9.6
# 1    控方证人   42995.0  剧情/悬疑/犯罪    美国  1957-12-17 00:00:00  116  1957  9.5
# 2   美丽人生   327855.0  剧情/喜剧/爱情   意大利  1997-12-20 00:00:00  116  1997  9.5
# 3    阿甘正传  580897.0     剧情/爱情    美国  1994-06-23 00:00:00  142  1994  9.4
# 4    霸王别姬  478523.0  剧情/爱情/同性  中国大陆  1993-01-01 00:00:00  171  1993  9.4
#
#      首映地点  序号  序号2  序号hh
# 0  多伦多电影节   1    1     0
# 1      美国   2    2     1
# 2     意大利   3    3     2
# 3   洛杉矶首映   4    4     3
# 4      香港   5    5     4

# %%
# 删除列
df = df.drop('序号hh', axis=1)

# %%
df
# Out:
#        名字      投票人数        类型    产地                 上映时间   时长    年代   评分  \
# 0  肖申克的救赎  692795.0     剧情/犯罪    美国  1994-09-10 00:00:00  142  1994  9.6
# 1    控方证人   42995.0  剧情/悬疑/犯罪    美国  1957-12-17 00:00:00  116  1957  9.5
# 2   美丽人生   327855.0  剧情/喜剧/爱情   意大利  1997-12-20 00:00:00  116  1997  9.5
# 3    阿甘正传  580897.0     剧情/爱情    美国  1994-06-23 00:00:00  142  1994  9.4
# 4    霸王别姬  478523.0  剧情/爱情/同性  中国大陆  1993-01-01 00:00:00  171  1993  9.4
#
#      首映地点
# 0  多伦多电影节
# 1      美国
# 2     意大利
# 3   洛杉矶首映
# 4      香港

# %%
dic = {
    '名字':'复仇者联盟3',
    '投票人数':4565142,
    '类型':'剧情/科幻',
    '产地':'美国',
    '上映时间':'1994-09-10 10:00:00',
    '时长':np.nan,
    '年代':1996,
    '评分':9.5,
    '首映地点':'美国'
}
s = pd.Series(dic)
s.name = 5
s
# Out:
# 名字                   复仇者联盟3
# 投票人数                4565142
# 类型                    剧情/科幻
# 产地                       美国
# 上映时间    1994-09-10 10:00:00
# 时长                      NaN
# 年代                     1996
# 评分                      9.5
# 首映地点                     美国
# Name: 5, dtype: object

# %%
# 添加一行，返回新的DataFrame
df2 = df.append(s)
df2
# Out:
#        名字       投票人数        类型    产地                 上映时间   时长    年代   评分  \
# 0  肖申克的救赎   692795.0     剧情/犯罪    美国  1994-09-10 00:00:00  142  1994  9.6
# 1    控方证人    42995.0  剧情/悬疑/犯罪    美国  1957-12-17 00:00:00  116  1957  9.5
# 2   美丽人生    327855.0  剧情/喜剧/爱情   意大利  1997-12-20 00:00:00  116  1997  9.5
# 3    阿甘正传   580897.0     剧情/爱情    美国  1994-06-23 00:00:00  142  1994  9.4
# 4    霸王别姬   478523.0  剧情/爱情/同性  中国大陆  1993-01-01 00:00:00  171  1993  9.4
# 5  复仇者联盟3  4565142.0     剧情/科幻    美国  1994-09-10 10:00:00  NaN  1996  9.5
#
#      首映地点   序号
# 0  多伦多电影节  1.0
# 1      美国  2.0
# 2     意大利  3.0
# 3   洛杉矶首映  4.0
# 4      香港  5.0
# 5      美国  NaN

# %%
df2.drop(5)
# Out:
#        名字      投票人数        类型    产地                 上映时间   时长    年代   评分  \
# 0  肖申克的救赎  692795.0     剧情/犯罪    美国  1994-09-10 00:00:00  142  1994  9.6
# 1    控方证人   42995.0  剧情/悬疑/犯罪    美国  1957-12-17 00:00:00  116  1957  9.5
# 2   美丽人生   327855.0  剧情/喜剧/爱情   意大利  1997-12-20 00:00:00  116  1997  9.5
# 3    阿甘正传  580897.0     剧情/爱情    美国  1994-06-23 00:00:00  142  1994  9.4
# 4    霸王别姬  478523.0  剧情/爱情/同性  中国大陆  1993-01-01 00:00:00  171  1993  9.4
#
#      首映地点
# 0  多伦多电影节
# 1      美国
# 2     意大利
# 3   洛杉矶首映
# 4      香港

# %%
df2.drop(5)
# Out:
#        名字      投票人数        类型    产地                 上映时间   时长    年代   评分  \
# 0  肖申克的救赎  692795.0     剧情/犯罪    美国  1994-09-10 00:00:00  142  1994  9.6
# 1    控方证人   42995.0  剧情/悬疑/犯罪    美国  1957-12-17 00:00:00  116  1957  9.5
# 2   美丽人生   327855.0  剧情/喜剧/爱情   意大利  1997-12-20 00:00:00  116  1997  9.5
# 3    阿甘正传  580897.0     剧情/爱情    美国  1994-06-23 00:00:00  142  1994  9.4
# 4    霸王别姬  478523.0  剧情/爱情/同性  中国大陆  1993-01-01 00:00:00  171  1993  9.4
#
#      首映地点
# 0  多伦多电影节
# 1      美国
# 2     意大利
# 3   洛杉矶首映
# 4      香港

# %%
df['序号'] = range(1, len(df)+1)

# %%
df
# Out:
#        名字      投票人数        类型    产地                 上映时间   时长    年代   评分  \
# 0  肖申克的救赎  692795.0     剧情/犯罪    美国  1994-09-10 00:00:00  142  1994  9.6
# 1    控方证人   42995.0  剧情/悬疑/犯罪    美国  1957-12-17 00:00:00  116  1957  9.5
# 2   美丽人生   327855.0  剧情/喜剧/爱情   意大利  1997-12-20 00:00:00  116  1997  9.5
# 3    阿甘正传  580897.0     剧情/爱情    美国  1994-06-23 00:00:00  142  1994  9.4
# 4    霸王别姬  478523.0  剧情/爱情/同性  中国大陆  1993-01-01 00:00:00  171  1993  9.4
#
#      首映地点  序号
# 0  多伦多电影节   1
# 1      美国   2
# 2     意大利   3
# 3   洛杉矶首映   4
# 4      香港   5

# %%
df = df.drop('序号', axis=1)

# %%
df
# Out:
#        名字      投票人数        类型    产地                 上映时间   时长    年代   评分  \
# 0  肖申克的救赎  692795.0     剧情/犯罪    美国  1994-09-10 00:00:00  142  1994  9.6
# 1    控方证人   42995.0  剧情/悬疑/犯罪    美国  1957-12-17 00:00:00  116  1957  9.5
# 2   美丽人生   327855.0  剧情/喜剧/爱情   意大利  1997-12-20 00:00:00  116  1997  9.5
# 3    阿甘正传  580897.0     剧情/爱情    美国  1994-06-23 00:00:00  142  1994  9.4
# 4    霸王别姬  478523.0  剧情/爱情/同性  中国大陆  1993-01-01 00:00:00  171  1993  9.4
#
#      首映地点
# 0  多伦多电影节
# 1      美国
# 2     意大利
# 3   洛杉矶首映
# 4      香港

# %%
dic = {
    '名字':'复仇者联盟3',
    '投票人数':4565142,
    '类型':'剧情/科幻',
    '产地':np.nan,,
    '上映时间':'1994-09-10 10:00:00',
    '时长':np.nan,
    '年代':1996,
    '评分':9.5,
    '首映地点':np.nan,
}
s = pd.Series(dic)
s.name = 5
df2 = df.append(s)
# Out:
# 名字                   复仇者联盟3
# 投票人数                4565142
# 类型                    剧情/科幻
# 产地                       美国
# 上映时间    1994-09-10 10:00:00
# 时长                      NaN
# 年代                     1996
# 评分                      9.5
# 首映地点                     美国
# Name: 5, dtype: object

# %%
df2 = df.append(s)

# %%
df2
# Out:
#        名字       投票人数        类型    产地                 上映时间   时长    年代   评分  \
# 0  肖申克的救赎   692795.0     剧情/犯罪    美国  1994-09-10 00:00:00  142  1994  9.6
# 1    控方证人    42995.0  剧情/悬疑/犯罪    美国  1957-12-17 00:00:00  116  1957  9.5
# 2   美丽人生    327855.0  剧情/喜剧/爱情   意大利  1997-12-20 00:00:00  116  1997  9.5
# 3    阿甘正传   580897.0     剧情/爱情    美国  1994-06-23 00:00:00  142  1994  9.4
# 4    霸王别姬   478523.0  剧情/爱情/同性  中国大陆  1993-01-01 00:00:00  171  1993  9.4
# 5  复仇者联盟3  4565142.0     剧情/科幻    美国  1994-09-10 10:00:00  NaN  1996  9.5
#
#      首映地点
# 0  多伦多电影节
# 1      美国
# 2     意大利
# 3   洛杉矶首映
# 4      香港
# 5      美国

# %%
df2
# Out:
#        名字       投票人数        类型    产地                 上映时间   时长    年代   评分  \
# 0  肖申克的救赎   692795.0     剧情/犯罪    美国  1994-09-10 00:00:00  142  1994  9.6
# 1    控方证人    42995.0  剧情/悬疑/犯罪    美国  1957-12-17 00:00:00  116  1957  9.5
# 2   美丽人生    327855.0  剧情/喜剧/爱情   意大利  1997-12-20 00:00:00  116  1997  9.5
# 3    阿甘正传   580897.0     剧情/爱情    美国  1994-06-23 00:00:00  142  1994  9.4
# 4    霸王别姬   478523.0  剧情/爱情/同性  中国大陆  1993-01-01 00:00:00  171  1993  9.4
# 5  复仇者联盟3  4565142.0     剧情/科幻    美国  1994-09-10 10:00:00  NaN  1996  9.5
#
#      首映地点
# 0  多伦多电影节
# 1      美国
# 2     意大利
# 3   洛杉矶首映
# 4      香港
# 5      美国

# %%
df2[df2['时长'].isnull()]
# Out:
#        名字       投票人数     类型  产地                 上映时间   时长    年代   评分 首映地点
# 5  复仇者联盟3  4565142.0  剧情/科幻  美国  1994-09-10 10:00:00  NaN  1996  9.5   美国

# %%
df2
df
# Out:
#        名字      投票人数        类型    产地                 上映时间   时长    年代   评分  \
# 0  肖申克的救赎  692795.0     剧情/犯罪    美国  1994-09-10 00:00:00  142  1994  9.6
# 1    控方证人   42995.0  剧情/悬疑/犯罪    美国  1957-12-17 00:00:00  116  1957  9.5
# 2   美丽人生   327855.0  剧情/喜剧/爱情   意大利  1997-12-20 00:00:00  116  1997  9.5
# 3    阿甘正传  580897.0     剧情/爱情    美国  1994-06-23 00:00:00  142  1994  9.4
# 4    霸王别姬  478523.0  剧情/爱情/同性  中国大陆  1993-01-01 00:00:00  171  1993  9.4
#
#      首映地点
# 0  多伦多电影节
# 1      美国
# 2     意大利
# 3   洛杉矶首映
# 4      香港

# %%
df2['时长'].fillna(np.mean(df['时长']), inplace=True)
# df['时长']

# %%
df2
# Out:
#        名字       投票人数        类型    产地                 上映时间           时长    年代  \
# 0  肖申克的救赎   692795.0     剧情/犯罪    美国  1994-09-10 00:00:00          142  1994
# 1    控方证人    42995.0  剧情/悬疑/犯罪    美国  1957-12-17 00:00:00          116  1957
# 2   美丽人生    327855.0  剧情/喜剧/爱情   意大利  1997-12-20 00:00:00          116  1997
# 3    阿甘正传   580897.0     剧情/爱情    美国  1994-06-23 00:00:00          142  1994
# 4    霸王别姬   478523.0  剧情/爱情/同性  中国大陆  1993-01-01 00:00:00          171  1993
# 5  复仇者联盟3  4565142.0     剧情/科幻    美国  1994-09-10 10:00:00  2.84232e+13  1996
#
#     评分    首映地点
# 0  9.6  多伦多电影节
# 1  9.5      美国
# 2  9.5     意大利
# 3  9.4   洛杉矶首映
# 4  9.4      香港
# 5  9.5      美国

# %%
df
# Out:
#        名字      投票人数        类型    产地                 上映时间   时长    年代   评分  \
# 0  肖申克的救赎  692795.0     剧情/犯罪    美国  1994-09-10 00:00:00  142  1994  9.6
# 1    控方证人   42995.0  剧情/悬疑/犯罪    美国  1957-12-17 00:00:00  116  1957  9.5
# 2   美丽人生   327855.0  剧情/喜剧/爱情   意大利  1997-12-20 00:00:00  116  1997  9.5
# 3    阿甘正传  580897.0     剧情/爱情    美国  1994-06-23 00:00:00  142  1994  9.4
# 4    霸王别姬  478523.0  剧情/爱情/同性  中国大陆  1993-01-01 00:00:00  171  1993  9.4
#
#      首映地点
# 0  多伦多电影节
# 1      美国
# 2     意大利
# 3   洛杉矶首映
# 4      香港

# %%
df2 = df.append(s)

# %%
df2
# Out:
#        名字       投票人数        类型    产地                 上映时间   时长    年代   评分  \
# 0  肖申克的救赎   692795.0     剧情/犯罪    美国  1994-09-10 00:00:00  142  1994  9.6
# 1    控方证人    42995.0  剧情/悬疑/犯罪    美国  1957-12-17 00:00:00  116  1957  9.5
# 2   美丽人生    327855.0  剧情/喜剧/爱情   意大利  1997-12-20 00:00:00  116  1997  9.5
# 3    阿甘正传   580897.0     剧情/爱情    美国  1994-06-23 00:00:00  142  1994  9.4
# 4    霸王别姬   478523.0  剧情/爱情/同性  中国大陆  1993-01-01 00:00:00  171  1993  9.4
# 5  复仇者联盟3  4565142.0     剧情/科幻    美国  1994-09-10 10:00:00  NaN  1996  9.5
#
#      首映地点
# 0  多伦多电影节
# 1      美国
# 2     意大利
# 3   洛杉矶首映
# 4      香港
# 5      美国

# %%
df2
# Out:
#        名字       投票人数        类型    产地                 上映时间   时长    年代   评分  \
# 0  肖申克的救赎   692795.0     剧情/犯罪    美国  1994-09-10 00:00:00  142  1994  9.6
# 1    控方证人    42995.0  剧情/悬疑/犯罪    美国  1957-12-17 00:00:00  116  1957  9.5
# 2   美丽人生    327855.0  剧情/喜剧/爱情   意大利  1997-12-20 00:00:00  116  1997  9.5
# 3    阿甘正传   580897.0     剧情/爱情    美国  1994-06-23 00:00:00  142  1994  9.4
# 4    霸王别姬   478523.0  剧情/爱情/同性  中国大陆  1993-01-01 00:00:00  171  1993  9.4
# 5  复仇者联盟3  4565142.0     剧情/科幻    美国  1994-09-10 10:00:00  NaN  1996  9.5
#
#      首映地点
# 0  多伦多电影节
# 1      美国
# 2     意大利
# 3   洛杉矶首映
# 4      香港
# 5      美国

# %%
# 找出非空的时长求平均值
sa = df2[~df2['时长'].isnull()]['时长'].astype(int)
avg_time = np.mean(sa)
# 填充空值，inplace设置为True是在原来数据上操作
df2['时长'].fillna(avg_time, inplace=True)

# %%
df2
# Out:
#        名字       投票人数        类型    产地                 上映时间     时长    年代   评分  \
# 0  肖申克的救赎   692795.0     剧情/犯罪    美国  1994-09-10 00:00:00    142  1994  9.6
# 1    控方证人    42995.0  剧情/悬疑/犯罪    美国  1957-12-17 00:00:00    116  1957  9.5
# 2   美丽人生    327855.0  剧情/喜剧/爱情   意大利  1997-12-20 00:00:00    116  1997  9.5
# 3    阿甘正传   580897.0     剧情/爱情    美国  1994-06-23 00:00:00    142  1994  9.4
# 4    霸王别姬   478523.0  剧情/爱情/同性  中国大陆  1993-01-01 00:00:00    171  1993  9.4
# 5  复仇者联盟3  4565142.0     剧情/科幻    美国  1994-09-10 10:00:00  137.4  1996  9.5
#
#      首映地点
# 0  多伦多电影节
# 1      美国
# 2     意大利
# 3   洛杉矶首映
# 4      香港
# 5      美国

# %%
df
# Out:
#        名字      投票人数        类型    产地                 上映时间   时长    年代   评分  \
# 0  肖申克的救赎  692795.0     剧情/犯罪    美国  1994-09-10 00:00:00  142  1994  9.6
# 1    控方证人   42995.0  剧情/悬疑/犯罪    美国  1957-12-17 00:00:00  116  1957  9.5
# 2   美丽人生   327855.0  剧情/喜剧/爱情   意大利  1997-12-20 00:00:00  116  1997  9.5
# 3    阿甘正传  580897.0     剧情/爱情    美国  1994-06-23 00:00:00  142  1994  9.4
# 4    霸王别姬  478523.0  剧情/爱情/同性  中国大陆  1993-01-01 00:00:00  171  1993  9.4
#
#      首映地点
# 0  多伦多电影节
# 1      美国
# 2     意大利
# 3   洛杉矶首映
# 4      香港

# %%
dic = {
    '名字':'复仇者联盟3',
    '投票人数':4565142,
    '类型':'剧情/科幻',
    '产地':np.nan,
    '上映时间':'1994-09-10 10:00:00',
    '时长':np.nan,
    '年代':1996,
    '评分':9.5,
    '首映地点':np.nan,
}
s = pd.Series(dic)
s.name = 5
df2 = df.append(s)

# %%
df2
# Out:
#        名字       投票人数        类型    产地                 上映时间   时长    年代   评分  \
# 0  肖申克的救赎   692795.0     剧情/犯罪    美国  1994-09-10 00:00:00  142  1994  9.6
# 1    控方证人    42995.0  剧情/悬疑/犯罪    美国  1957-12-17 00:00:00  116  1957  9.5
# 2   美丽人生    327855.0  剧情/喜剧/爱情   意大利  1997-12-20 00:00:00  116  1997  9.5
# 3    阿甘正传   580897.0     剧情/爱情    美国  1994-06-23 00:00:00  142  1994  9.4
# 4    霸王别姬   478523.0  剧情/爱情/同性  中国大陆  1993-01-01 00:00:00  171  1993  9.4
# 5  复仇者联盟3  4565142.0     剧情/科幻   NaN  1994-09-10 10:00:00  NaN  1996  9.5
#
#      首映地点
# 0  多伦多电影节
# 1      美国
# 2     意大利
# 3   洛杉矶首映
# 4      香港
# 5     NaN

# %%
# 对所有空值进行填充
df2.fillna('- - -')
# Out:
#        名字       投票人数        类型     产地                 上映时间     时长    年代   评分  \
# 0  肖申克的救赎   692795.0     剧情/犯罪     美国  1994-09-10 00:00:00    142  1994  9.6
# 1    控方证人    42995.0  剧情/悬疑/犯罪     美国  1957-12-17 00:00:00    116  1957  9.5
# 2   美丽人生    327855.0  剧情/喜剧/爱情    意大利  1997-12-20 00:00:00    116  1997  9.5
# 3    阿甘正传   580897.0     剧情/爱情     美国  1994-06-23 00:00:00    142  1994  9.4
# 4    霸王别姬   478523.0  剧情/爱情/同性   中国大陆  1993-01-01 00:00:00    171  1993  9.4
# 5  复仇者联盟3  4565142.0     剧情/科幻  - - -  1994-09-10 10:00:00  - - -  1996  9.5
#
#      首映地点
# 0  多伦多电影节
# 1      美国
# 2     意大利
# 3   洛杉矶首映
# 4      香港
# 5   - - -

# %%
df
# Out:
#        名字      投票人数        类型    产地                 上映时间   时长    年代   评分  \
# 0  肖申克的救赎  692795.0     剧情/犯罪    美国  1994-09-10 00:00:00  142  1994  9.6
# 1    控方证人   42995.0  剧情/悬疑/犯罪    美国  1957-12-17 00:00:00  116  1957  9.5
# 2   美丽人生   327855.0  剧情/喜剧/爱情   意大利  1997-12-20 00:00:00  116  1997  9.5
# 3    阿甘正传  580897.0     剧情/爱情    美国  1994-06-23 00:00:00  142  1994  9.4
# 4    霸王别姬  478523.0  剧情/爱情/同性  中国大陆  1993-01-01 00:00:00  171  1993  9.4
#
#      首映地点
# 0  多伦多电影节
# 1      美国
# 2     意大利
# 3   洛杉矶首映
# 4      香港

# %%
df2
# Out:
#        名字       投票人数        类型    产地                 上映时间   时长    年代   评分  \
# 0  肖申克的救赎   692795.0     剧情/犯罪    美国  1994-09-10 00:00:00  142  1994  9.6
# 1    控方证人    42995.0  剧情/悬疑/犯罪    美国  1957-12-17 00:00:00  116  1957  9.5
# 2   美丽人生    327855.0  剧情/喜剧/爱情   意大利  1997-12-20 00:00:00  116  1997  9.5
# 3    阿甘正传   580897.0     剧情/爱情    美国  1994-06-23 00:00:00  142  1994  9.4
# 4    霸王别姬   478523.0  剧情/爱情/同性  中国大陆  1993-01-01 00:00:00  171  1993  9.4
# 5  复仇者联盟4  4565142.0     剧情/科幻    美国  2019-01-10 10:00:00  196   NaN  NaN
#
#      首映地点
# 0  多伦多电影节
# 1      美国
# 2     意大利
# 3   洛杉矶首映
# 4      香港
# 5      美国

# %%
dic = {
    '名字':'复仇者联盟4',
    '投票人数':4565142,
    '类型':'剧情/科幻',
    '产地':'美国',
    '上映时间':'2019-01-10 10:00:00',
    '时长':196,
    '年代':np.nan,
    '评分':np.nan,
    '首映地点':'美国',
}
s = pd.Series(dic)
s.name = 6
df2 = df2.append(s)

# %%
df2
# Out:
#        名字       投票人数        类型    产地                 上映时间   时长    年代   评分  \
# 0  肖申克的救赎   692795.0     剧情/犯罪    美国  1994-09-10 00:00:00  142  1994  9.6
# 1    控方证人    42995.0  剧情/悬疑/犯罪    美国  1957-12-17 00:00:00  116  1957  9.5
# 2   美丽人生    327855.0  剧情/喜剧/爱情   意大利  1997-12-20 00:00:00  116  1997  9.5
# 3    阿甘正传   580897.0     剧情/爱情    美国  1994-06-23 00:00:00  142  1994  9.4
# 4    霸王别姬   478523.0  剧情/爱情/同性  中国大陆  1993-01-01 00:00:00  171  1993  9.4
# 5  复仇者联盟3  4565142.0     剧情/科幻   NaN  1994-09-10 10:00:00  NaN  1996  9.5
# 6  复仇者联盟4  4565142.0     剧情/科幻    美国  2019-01-10 10:00:00  196   NaN  NaN
#
#      首映地点
# 0  多伦多电影节
# 1      美国
# 2     意大利
# 3   洛杉矶首映
# 4      香港
# 5     NaN
# 6      美国

# %%
df2.dropna(inplace=True)

# %%
df2
# Out:
#        名字      投票人数        类型    产地                 上映时间   时长    年代   评分  \
# 0  肖申克的救赎  692795.0     剧情/犯罪    美国  1994-09-10 00:00:00  142  1994  9.6
# 1    控方证人   42995.0  剧情/悬疑/犯罪    美国  1957-12-17 00:00:00  116  1957  9.5
# 2   美丽人生   327855.0  剧情/喜剧/爱情   意大利  1997-12-20 00:00:00  116  1997  9.5
# 3    阿甘正传  580897.0     剧情/爱情    美国  1994-06-23 00:00:00  142  1994  9.4
# 4    霸王别姬  478523.0  剧情/爱情/同性  中国大陆  1993-01-01 00:00:00  171  1993  9.4
#
#      首映地点
# 0  多伦多电影节
# 1      美国
# 2     意大利
# 3   洛杉矶首映
# 4      香港

# %%
len(data)
# Out:
# 90

# %%
df
# Out:
#        名字      投票人数        类型    产地                 上映时间   时长    年代   评分  \
# 0  肖申克的救赎  692795.0     剧情/犯罪    美国  1994-09-10 00:00:00  142  1994  9.6
# 1    控方证人   42995.0  剧情/悬疑/犯罪    美国  1957-12-17 00:00:00  116  1957  9.5
# 2   美丽人生   327855.0  剧情/喜剧/爱情   意大利  1997-12-20 00:00:00  116  1997  9.5
# 3    阿甘正传  580897.0     剧情/爱情    美国  1994-06-23 00:00:00  142  1994  9.4
# 4    霸王别姬  478523.0  剧情/爱情/同性  中国大陆  1993-01-01 00:00:00  171  1993  9.4
#
#      首映地点
# 0  多伦多电影节
# 1      美国
# 2     意大利
# 3   洛杉矶首映
# 4      香港

# %%
df.名字
# Out:
# 0    肖申克的救赎
# 1      控方证人
# 2     美丽人生
# 3      阿甘正传
# 4      霸王别姬
# Name: 名字, dtype: object

# %%
df.to_excel('asd.xlsx')

# %%
df
# Out:
#        名字      投票人数        类型    产地                 上映时间   时长    年代   评分  \
# 0  肖申克的救赎  692795.0     剧情/犯罪    美国  1994-09-10 00:00:00  142  1994  9.6
# 1    控方证人   42995.0  剧情/悬疑/犯罪    美国  1957-12-17 00:00:00  116  1957  9.5
# 2   美丽人生   327855.0  剧情/喜剧/爱情   意大利  1997-12-20 00:00:00  116  1997  9.5
# 3    阿甘正传  580897.0     剧情/爱情    美国  1994-06-23 00:00:00  142  1994  9.4
# 4    霸王别姬  478523.0  剧情/爱情/同性  中国大陆  1993-01-01 00:00:00  171  1993  9.4
#
#      首映地点
# 0  多伦多电影节
# 1      美国
# 2     意大利
# 3   洛杉矶首映
# 4      香港

# %%
data
# Out:
#       city                company           company_number company_size  \
# 0       杭州         北京建设数字科技股份有限公司              CZ000325840     100-499人
# 1       杭州         杭州对点人力资源管理有限公司              CZ414409920     100-499人
# 2       杭州           杭州皮森教育科技有限公司              CZ393123780       20-99人
# 3   杭州-余杭区               圆通速递有限公司              CZ138773160     10000人以上
# 4       杭州             杭州数美科技有限公司              CZ504452280     100-499人
# 5    杭州-下沙         杭州沃镭智能科技股份有限公司              CZ346054610     100-499人
# 6       杭州           杭州金时资产管理有限公司              CZ573260080       20-99人
# 7   杭州-江干区         视联动力信息技术股份有限公司              CZ397785110   1000-9999人
# 8   杭州-江干区         视联动力信息技术股份有限公司              CZ397785110   1000-9999人
# 9   杭州-江干区         视联动力信息技术股份有限公司              CZ397785110   1000-9999人
# 10  杭州-江干区         视联动力信息技术股份有限公司              CZ397785110   1000-9999人
# 11  杭州-拱墅区         京东数字科技控股有限公司    CZ192921310D00112072216   1000-9999人
# ...

# %%
df = mov[:10]

# %%
df
# Out:
#                                       名字      投票人数              类型    产地  \
# 0                                 肖申克的救赎  692795.0           剧情/犯罪    美国
# 1                                   控方证人   42995.0        剧情/悬疑/犯罪    美国
# 2                                  美丽人生   327855.0        剧情/喜剧/爱情   意大利
# 3                                   阿甘正传  580897.0           剧情/爱情    美国
# 4                                   霸王别姬  478523.0        剧情/爱情/同性  中国大陆
# 5                                 泰坦尼克号   157074.0        剧情/爱情/灾难    美国
# 6                                 辛德勒的名单  306904.0        剧情/历史/战争    美国
# 7  新世纪福音战士剧场版：Air/真心为你 新世紀エヴァンゲリオン劇場版 Ai   24355.0  剧情/动作/科幻/动画/奇幻    日本
# 8         银魂完结篇：直到永远的万事屋 劇場版 銀魂 完結篇 万事屋よ   21513.0           剧情/动画    日本
# 9                               这个杀手不太冷   662552.0        剧情/动作/犯罪    法国
#
#                   上映时间   时长    年代   评分    首映地点
# 0  1994-09-10 00:00:00  142  1994  9.6  多伦多电影节
# 1  1957-12-17 00:00:00  116  1957  9.5      美国
# ...

# %%
df.时长.dtype
# Out:
# dtype('O')

# %%
df.sort_values(by='上映时间', ascending=False)
# Out:
#                                       名字      投票人数              类型    产地  \
# 8         银魂完结篇：直到永远的万事屋 劇場版 銀魂 完結篇 万事屋よ   21513.0           剧情/动画    日本
# 5                                 泰坦尼克号   157074.0        剧情/爱情/灾难    美国
# 2                                  美丽人生   327855.0        剧情/喜剧/爱情   意大利
# 7  新世纪福音战士剧场版：Air/真心为你 新世紀エヴァンゲリオン劇場版 Ai   24355.0  剧情/动作/科幻/动画/奇幻    日本
# 9                               这个杀手不太冷   662552.0        剧情/动作/犯罪    法国
# 0                                 肖申克的救赎  692795.0           剧情/犯罪    美国
# 3                                   阿甘正传  580897.0           剧情/爱情    美国
# 6                                 辛德勒的名单  306904.0        剧情/历史/战争    美国
# 4                                   霸王别姬  478523.0        剧情/爱情/同性  中国大陆
# 1                                   控方证人   42995.0        剧情/悬疑/犯罪    美国
#
#                   上映时间   时长    年代   评分    首映地点
# 8  2013-07-06 00:00:00  110  2013  9.4      日本
# 5  2012-04-10 00:00:00  194  2012  9.4    中国大陆
# ...

# %%
df.sort_values(by=['评分', '上映时间'], ascending=False)
# Out:
#                                       名字      投票人数              类型    产地  \
# 0                                 肖申克的救赎  692795.0           剧情/犯罪    美国
# 2                                  美丽人生   327855.0        剧情/喜剧/爱情   意大利
# 1                                   控方证人   42995.0        剧情/悬疑/犯罪    美国
# 8         银魂完结篇：直到永远的万事屋 劇場版 銀魂 完結篇 万事屋よ   21513.0           剧情/动画    日本
# 5                                 泰坦尼克号   157074.0        剧情/爱情/灾难    美国
# 7  新世纪福音战士剧场版：Air/真心为你 新世紀エヴァンゲリオン劇場版 Ai   24355.0  剧情/动作/科幻/动画/奇幻    日本
# 9                               这个杀手不太冷   662552.0        剧情/动作/犯罪    法国
# 3                                   阿甘正传  580897.0           剧情/爱情    美国
# 6                                 辛德勒的名单  306904.0        剧情/历史/战争    美国
# 4                                   霸王别姬  478523.0        剧情/爱情/同性  中国大陆
#
#                   上映时间   时长    年代   评分    首映地点
# 0  1994-09-10 00:00:00  142  1994  9.6  多伦多电影节
# 2  1997-12-20 00:00:00  116  1997  9.5     意大利
# ...
