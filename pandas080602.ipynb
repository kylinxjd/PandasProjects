# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel('豆瓣电影数据.xlsx', index_column=0)

# %%
df = data[:10]

# %%
df
# Out:
#    Unnamed: 0                                     名字      投票人数  \
# 0           0                                 肖申克的救赎  692795.0
# 1           1                                   控方证人   42995.0
# 2           2                                  美丽人生   327855.0
# 3           3                                   阿甘正传  580897.0
# 4           4                                   霸王别姬  478523.0
# 5           5                                 泰坦尼克号   157074.0
# 6           6                                 辛德勒的名单  306904.0
# 7           7  新世纪福音战士剧场版：Air/真心为你 新世紀エヴァンゲリオン劇場版 Ai   24355.0
# 8           8         银魂完结篇：直到永远的万事屋 劇場版 銀魂 完結篇 万事屋よ   21513.0
# 9           9                               这个杀手不太冷   662552.0
#
#                类型    产地                 上映时间   时长    年代   评分    首映地点
# 0           剧情/犯罪    美国  1994-09-10 00:00:00  142  1994  9.6  多伦多电影节
# 1        剧情/悬疑/犯罪    美国  1957-12-17 00:00:00  116  1957  9.5      美国
# ...

# %%
s = pd.Series(np.random.randint(-10,10,7), 
              index=[['a','a','b','b','c','c','c'],[0,1,0,1,0,1,2]])

# %%
s
# Out:
# a  0   -1
#    1    5
# b  0   -8
#    1    1
# c  0    1
#    1   -9
#    2    6
# dtype: int32

# %%
s.index
# Out:
# MultiIndex(levels=[['a', 'b', 'c'], [0, 1, 2]],
#            codes=[[0, 0, 1, 1, 2, 2, 2], [0, 1, 0, 1, 0, 1, 2]])

# %%
s['a', 1]
# Out:
# 5

# %%
s['a']
# Out:
# 0   -1
# 1    5
# dtype: int32

# %%
s['a':'b']  # 左闭右闭
# Out:
# a  0   -1
#    1    5
# b  0   -8
#    1    1
# dtype: int32

# %%
s
# Out:
# a  0   -1
#    1    5
# b  0   -8
#    1    1
# c  0    1
#    1   -9
#    2    6
# dtype: int32

# %%
s[ :, 0]
# Out:
# a   -1
# b   -8
# c    1
# dtype: int32

# %%
s['a', 1]
# Out:
# 5

# %%
d = s.unstack()
d
# Out:
#      0    1    2
# a -1.0  5.0  NaN
# b -8.0  1.0  NaN
# c  1.0 -9.0  6.0

# %%
d
# Out:
#      0    1    2
# a -1.0  5.0  NaN
# b -8.0  1.0  NaN
# c  1.0 -9.0  6.0

# %%
d.stack()
# Out:
# a  0   -1.0
#    1    5.0
# b  0   -8.0
#    1    1.0
# c  0    1.0
#    1   -9.0
#    2    6.0
# dtype: float64

# %%
s
# Out:
# a  0   -1
#    1    5
# b  0   -8
#    1    1
# c  0    1
#    1   -9
#    2    6
# dtype: int32

# %%
s.swaplevel()
# Out:
# 0  a   -1
# 1  a    5
# 0  b   -8
# 1  b    1
# 0  c    1
# 1  c   -9
# 2  c    6
# dtype: int32

# %%
s = pd.Series(np.random.randint(-10,10,6), pd.MultiIndex.from_product([['one', 'two'], ['a', 'b', 'c']]))

# %%
s
# Out:
# one  a    5
#      b    3
#      c    2
# two  a    3
#      b    5
#      c    4
# dtype: int32

# %%
s.index
# Out:
# MultiIndex(levels=[['one', 'two'], ['a', 'b', 'c']],
#            codes=[[0, 0, 0, 1, 1, 1], [0, 1, 2, 0, 1, 2]])

# %%
d = pd.DataFrame(np.arange(12).reshape(4,3),
                index=[['a','a','b','b'],[1,2,1,2]],
                columns=[['A','A','B'],['i','j','k']])
d
# Out:
#      A       B
#      i   j   k
# a 1  0   1   2
#   2  3   4   5
# b 1  6   7   8
#   2  9  10  11

# %%
d['A']
# Out:
#      i   j
# a 1  0   1
#   2  3   4
# b 1  6   7
#   2  9  10

# %%
data
# Out:
#        Unnamed: 0                                                 名字  \
# 0               0                                             肖申克的救赎
# 1               1                                               控方证人
# 2               2                                              美丽人生
# 3               3                                               阿甘正传
# 4               4                                               霸王别姬
# 5               5                                             泰坦尼克号
# 6               6                                             辛德勒的名单
# 7               7              新世纪福音战士剧场版：Air/真心为你 新世紀エヴァンゲリオン劇場版 Ai
# 8               8                     银魂完结篇：直到永远的万事屋 劇場版 銀魂 完結篇 万事屋よ
# 9               9                                           这个杀手不太冷
# 10             10                                              灿烂人生
# 11             11                                              疯狂动物城
# 12             12                           福音战士新剧场版：破 ヱヴァンゲリヲン新劇場版：
# ...

# %%
df = data[:50]
df
# Out:
#     Unnamed: 0                                     名字      投票人数  \
# 0            0                                 肖申克的救赎  692795.0
# 1            1                                   控方证人   42995.0
# 2            2                                  美丽人生   327855.0
# 3            3                                   阿甘正传  580897.0
# 4            4                                   霸王别姬  478523.0
# 5            5                                 泰坦尼克号   157074.0
# 6            6                                 辛德勒的名单  306904.0
# 7            7  新世纪福音战士剧场版：Air/真心为你 新世紀エヴァンゲリオン劇場版 Ai   24355.0
# 8            8         银魂完结篇：直到永远的万事屋 劇場版 銀魂 完結篇 万事屋よ   21513.0
# 9            9                               这个杀手不太冷   662552.0
# 10          10                                  灿烂人生    16807.0
# 11          11                                  疯狂动物城  284652.0
# 12          12               福音战士新剧场版：破 ヱヴァンゲリヲン新劇場版：   32524.0
# 13          13                                    海豚湾  159302.0
# ...

# %%
df2 = df.set_index(['产地','年代'])

# %%
df2
# Out:
#            Unnamed: 0                                     名字      投票人数  \
# 产地   年代
# 美国   1994           0                                 肖申克的救赎  692795.0
#      1957           1                                   控方证人   42995.0
# 意大利  1997           2                                  美丽人生   327855.0
# 美国   1994           3                                   阿甘正传  580897.0
# 中国大陆 1993           4                                   霸王别姬  478523.0
# 美国   2012           5                                 泰坦尼克号   157074.0
#      1993           6                                 辛德勒的名单  306904.0
# 日本   1997           7  新世纪福音战士剧场版：Air/真心为你 新世紀エヴァンゲリオン劇場版 Ai   24355.0
#      2013           8         银魂完结篇：直到永远的万事屋 劇場版 銀魂 完結篇 万事屋よ   21513.0
# 法国   1994           9                               这个杀手不太冷   662552.0
# 意大利  2003          10                                  灿烂人生    16807.0
# 美国   2016          11                                  疯狂动物城  284652.0
# ...

# %%
df2.index[0]
# Out:
# ('美国', 1994)

# %%
df2.loc['中国大陆']
# Out:
#       Unnamed: 0           名字      投票人数        类型                 上映时间   时长  \
# 年代
# 1993           4         霸王别姬  478523.0  剧情/爱情/同性  1993-01-01 00:00:00  171
# 1961          21         大闹天宫   74881.0     动画/奇幻  1905-05-14 00:00:00  114
# 2015          29         穹顶之下   51113.0       纪录片  2015-02-28 00:00:00  104
# 1982          38           茶馆   10678.0     剧情/历史  1905-06-04 00:00:00  118
# 1988          45          山水情   10781.0     动画/短片  1905-06-10 00:00:00   19
# 2016          49  “人权卫士”的人权纪录     109.0       纪录片  2016-03-13 00:00:00   45
#
#        评分  首映地点
# 年代
# 1993  9.4    香港
# 1961  9.2    上集
# 2015  9.2  中国大陆
# 1982  9.2    美国
# 1988  9.2    美国
# 2016  5.6  中国大陆

# %%
df2.swaplevel()
# Out:
#            Unnamed: 0                                     名字      投票人数  \
# 年代   产地
# 1994 美国             0                                 肖申克的救赎  692795.0
# 1957 美国             1                                   控方证人   42995.0
# 1997 意大利            2                                  美丽人生   327855.0
# 1994 美国             3                                   阿甘正传  580897.0
# 1993 中国大陆           4                                   霸王别姬  478523.0
# 2012 美国             5                                 泰坦尼克号   157074.0
# 1993 美国             6                                 辛德勒的名单  306904.0
# 1997 日本             7  新世纪福音战士剧场版：Air/真心为你 新世紀エヴァンゲリオン劇場版 Ai   24355.0
# 2013 日本             8         银魂完结篇：直到永远的万事屋 劇場版 銀魂 完結篇 万事屋よ   21513.0
# 1994 法国             9                               这个杀手不太冷   662552.0
# 2003 意大利           10                                  灿烂人生    16807.0
# 2016 美国            11                                  疯狂动物城  284652.0
# ...

# %%
df2.reset_index()
# Out:
#       产地    年代  Unnamed: 0                                     名字      投票人数  \
# 0     美国  1994           0                                 肖申克的救赎  692795.0
# 1     美国  1957           1                                   控方证人   42995.0
# 2    意大利  1997           2                                  美丽人生   327855.0
# 3     美国  1994           3                                   阿甘正传  580897.0
# 4   中国大陆  1993           4                                   霸王别姬  478523.0
# 5     美国  2012           5                                 泰坦尼克号   157074.0
# 6     美国  1993           6                                 辛德勒的名单  306904.0
# 7     日本  1997           7  新世纪福音战士剧场版：Air/真心为你 新世紀エヴァンゲリオン劇場版 Ai   24355.0
# 8     日本  2013           8         银魂完结篇：直到永远的万事屋 劇場版 銀魂 完結篇 万事屋よ   21513.0
# 9     法国  1994           9                               这个杀手不太冷   662552.0
# 10   意大利  2003          10                                  灿烂人生    16807.0
# ...

# %%
data = pd.read_excel('豆瓣电影数据.xlsx', index_col=0)
df = data[:6]

# %%
df
# Out:
#        名字      投票人数        类型    产地                 上映时间   时长    年代   评分  \
# 0  肖申克的救赎  692795.0     剧情/犯罪    美国  1994-09-10 00:00:00  142  1994  9.6
# 1    控方证人   42995.0  剧情/悬疑/犯罪    美国  1957-12-17 00:00:00  116  1957  9.5
# 2   美丽人生   327855.0  剧情/喜剧/爱情   意大利  1997-12-20 00:00:00  116  1997  9.5
# 3    阿甘正传  580897.0     剧情/爱情    美国  1994-06-23 00:00:00  142  1994  9.4
# 4    霸王别姬  478523.0  剧情/爱情/同性  中国大陆  1993-01-01 00:00:00  171  1993  9.4
# 5  泰坦尼克号   157074.0  剧情/爱情/灾难    美国  2012-04-10 00:00:00  194  2012  9.4
#
#      首映地点
# 0  多伦多电影节
# 1      美国
# 2     意大利
# 3   洛杉矶首映
# 4      香港
# 5    中国大陆
