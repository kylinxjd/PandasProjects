# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('欧洲国家旅游收入近20年数据.csv', skiprows=3, index_col=0, skipfooter=2, encoding='gbk')

# %%
data
# Out:
#                 比利时            丹麦            英国            德国            法国  \
# 时间
# 2015年  1.308400e+10  6.685000e+09  6.074400e+10  4.739300e+10  5.400300e+10
# 2014年  1.523500e+10  7.617000e+09  5.893500e+10  5.593900e+10  6.680300e+10
# 2013年  1.453600e+10  6.490000e+09  5.305200e+10  5.531800e+10  6.604900e+10
# 2012年  1.371100e+10  6.135000e+09  4.707000e+10  5.164500e+10  6.400100e+10
# 2011年  1.274200e+10  6.366000e+09  4.474100e+10  5.343100e+10  6.608700e+10
# 2010年  1.139500e+10  5.704000e+09  4.013800e+10  4.912800e+10  5.618700e+10
# 2009年  1.142300e+10  5.617000e+09  3.727200e+10  4.746200e+10  5.885800e+10
# 2008年  1.201800e+10  6.281000e+09  4.628300e+10  5.340000e+10  6.800100e+10
# 2007年  1.237100e+10  5.978000e+09  4.861800e+10  4.933300e+10  6.390200e+10
# 2006年  1.162500e+10  5.562000e+09  4.428400e+10  4.553700e+10  5.458700e+10
# 2005年  1.088100e+10  5.293000e+09  3.968400e+10  4.053100e+10  5.213900e+10
# ...

# %%
dad = data

# %%
pd.set_option('display.max_columns',100)

# %%
dad
# Out:
#                 比利时            丹麦            英国            德国            法国  \
# 时间
# 2015年  1.308400e+10  6.685000e+09  6.074400e+10  4.739300e+10  5.400300e+10
# 2014年  1.523500e+10  7.617000e+09  5.893500e+10  5.593900e+10  6.680300e+10
# 2013年  1.453600e+10  6.490000e+09  5.305200e+10  5.531800e+10  6.604900e+10
# 2012年  1.371100e+10  6.135000e+09  4.707000e+10  5.164500e+10  6.400100e+10
# 2011年  1.274200e+10  6.366000e+09  4.474100e+10  5.343100e+10  6.608700e+10
# 2010年  1.139500e+10  5.704000e+09  4.013800e+10  4.912800e+10  5.618700e+10
# 2009年  1.142300e+10  5.617000e+09  3.727200e+10  4.746200e+10  5.885800e+10
# 2008年  1.201800e+10  6.281000e+09  4.628300e+10  5.340000e+10  6.800100e+10
# 2007年  1.237100e+10  5.978000e+09  4.861800e+10  4.933300e+10  6.390200e+10
# 2006年  1.162500e+10  5.562000e+09  4.428400e+10  4.553700e+10  5.458700e+10
# 2005年  1.088100e+10  5.293000e+09  3.968400e+10  4.053100e+10  5.213900e+10
# ...

# %%
dad.isnull().any(axis=1)
# Out:
# 时间
# 2015年    True
# 2014年    True
# 2013年    True
# 2012年    True
# 2011年    True
# 2010年    True
# 2009年    True
# 2008年    True
# 2007年    True
# 2006年    True
# 2005年    True
# 2004年    True
# 2003年    True
# 2002年    True
# 2001年    True
# 2000年    True
# 1999年    True
# 1998年    True
# 1997年    True
# 1996年    True
# dtype: bool

# %%
df=data.dropna(axis=1)

# %%
df = df.sort_index()

# %%
# 修改字体，支持中文
plt.rcParams['font.sans-serif'] = ['SimHei']
# 当字体是中文的时候显示负号
plt.rcParams['axes.unicode_minus'] = False

# %%
su = df.sum(axis=1)/10**8
plt.figure(figsize=(12, 8))
plt.title('欧洲近二十年旅游收入', fontsize=20)
plt.xticks(fontsize=14, rotation=45)
plt.yticks(fontsize=14)
plt.ylabel('收入（亿元）', fontsize=18)
plt.plot(su.index, su.values, 'b', marker='o', markersize=10, markerfacecolor='g')
plt.show()

# %%
plt.figure(2, (30, 10))
plt.xticks(range(20), df.index, fontsize=14)
plt.yticks(fontsize=18)

x1 = [i - 0.2 for i in list(range(20))]
x2 = [i for i in list(range(20))]
x3 = [i + 0.2 for i in list(range(20))]
plt.bar(x1, df['比利时'].values, width=0.2, label='比利时')
plt.bar(x2, df['丹麦'].values, width=0.2, label='丹麦')
plt.bar(x3, df['爱尔兰'].values, width=0.2, label='爱尔兰')

# for a, b, c, d in zip(x2, df['比利时'].values, df['丹麦'].values, df['爱尔兰'].values):
#     plt.text(a, b+550, b, ha='center', va='bottom', fontsize=20)

plt.legend(loc=2)

# %%
plt.figure(3, (30, 10))
plt.xticks(fontsize=14)
plt.yticks(fontsize=18)
plt.yticks(fontsize=14)
plt.ylabel('收入（亿元）', fontsize=18)

plt.plot(df.index, df['比利时'].values/10**8, 'g', marker='o', markerfacecolor='b', label='比利时')
plt.plot(df.index, df['丹麦'].values/10**8, 'r', marker='o', markerfacecolor='b', label='丹麦')
plt.plot(df.index, df['爱尔兰'].values/10**8, 'b', marker='o', markerfacecolor='b', label='爱尔兰')

plt.legend(loc=2, fontsize='large')

# %%
from pyecharts.charts import Bar
from pyecharts import options as opts
from pyecharts.globals import ThemeType
# V1 版本开始支持链式调用
bar = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.LIGHT))
    .add_xaxis(list(df.index))
    .add_yaxis("比利时", df['比利时'].values.tolist())
    .add_yaxis("丹麦", df['丹麦'].values.tolist())
    .add_yaxis("爱尔兰", df['爱尔兰'].values.tolist())
    .set_global_opts(title_opts=opts.TitleOpts(title="比利时、丹麦、爱尔兰旅游收入对比"))
)
# bar.render()
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="9f1931ffad42402cbb45ffcfdd3cb291" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_9f1931ffad42402cbb45ffcfdd3cb291 = echarts.init(
#             document.getElementById('9f1931ffad42402cbb45ffcfdd3cb291'), 'light', {renderer: 'canvas'});
#         var option_9f1931ffad42402cbb45ffcfdd3cb291 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u6bd4\u5229\u65f6",
#             "data": [
#                 4844000000.0,
# ...

# %%
df['比利时'].values.tolist()
# Out:
# [4844000000.0,
#  4529000000.0,
#  4623000000.0,
#  6472000000.0,
#  6592000000.0,
#  8304000000.0,
#  7598000000.0,
#  8848000000.0,
#  10089000000.0,
#  10881000000.0,
#  11625000000.0,
#  12371000000.0,
#  12018000000.0,
#  11423000000.0,
#  11395000000.0,
#  12742000000.0,
#  13711000000.0,
#  14536000000.0,
#  15235000000.0,
#  13084000000.0]

# %%
cdata = pd.read_csv('中国近10年各项税收数据.csv',skiprows=2, index_col=0, skipfooter=1,  encoding='gbk')
cdata
# Out:
#                2016年      2015年      2014年      2013年      2012年     2011年  \
# 指标
# 企业所得税(亿元)   28851.36   27133.87   24642.19   22427.20   19654.53  16769.64
# 2014年   24642.19    7376.61   30855.36  17781.73    8907.12  2843.41
# 2015年   27133.87    8617.27   31109.47  19312.84   10542.16  2560.84
# 2016年   28851.36   10088.98   40712.08  11501.88   10217.23  2603.75
#
# 指标      各项税收(亿元)
# 2007年   45621.97
# 2008年   54223.79
# 2009年   59521.59
# 2010年   73210.79
# 2011年   89738.39
# 2012年  100614.28
# 2013年  110530.70
# 2014年  119175.31
# 2015年  124922.20
# 2016年  130360.73

# %%
from bokeh.io import omutput_file  # 生成HTML文档
from bokeh.io import output_notebook

# %%
np.random.randn(2000)
# Out:
# array([ 0.05790697, -0.81659722, -1.27720761, ...,  1.47621894,
#         1.04040736,  0.01770997])

# %%
vf = pd.DataFrame(np.random.randint(1, 12, (3, 4)))
vf['4'] = pd.Series(np.array([np.nan,np.nan,np.nan]))
vf.isnull()
# Out:
#        0      1      2      3     4
# 0  False  False  False  False  True
# 1  False  False  False  False  True
# 2  False  False  False  False  True

# %%
vf.isnull().any(axis=1)
# Out:
# 0    True
# 1    True
# 2    True
# dtype: bool

# %%
from bokeh.plotting import figure, show, output_file

# generate some synthetic time series for six different categories
cats = list("abcdef")
yy = np.random.randn(2000)
g = np.random.choice(cats, 2000)
for i, l in enumerate(cats):
    yy[g == l] += i // 2
df = pd.DataFrame(dict(score=yy, group=g))

# find the quartiles and IQR for each category
groups = df.groupby('group')
q1 = groups.quantile(q=0.25)
q2 = groups.quantile(q=0.5)
q3 = groups.quantile(q=0.75)
iqr = q3 - q1
upper = q3 + 1.5*iqr
lower = q1 - 1.5*iqr

# find the outliers for each category
def outliers(group):
    cat = group.name
    return group[(group.score > upper.loc[cat]['score']) | (group.score < lower.loc[cat]['score'])]['score']
out = groups.apply(outliers).dropna()

# prepare outlier data for plotting, we need coordinates for every outlier.
if not out.empty:
    outx = []
    outy = []
    for keys in out.index:
        outx.append(keys[0])
        outy.append(out.loc[keys[0]].loc[keys[1]])

p = figure(tools="", background_fill_color="#efefef", x_range=cats, toolbar_location=None)

# if no outliers, shrink lengths of stems to be no longer than the minimums or maximums
qmin = groups.quantile(q=0.00)
qmax = groups.quantile(q=1.00)
upper.score = [min([x,y]) for (x,y) in zip(list(qmax.loc[:,'score']),upper.score)]
lower.score = [max([x,y]) for (x,y) in zip(list(qmin.loc[:,'score']),lower.score)]

# stems
p.segment(cats, upper.score, cats, q3.score, line_color="black")
p.segment(cats, lower.score, cats, q1.score, line_color="black")

# boxes
p.vbar(cats, 0.7, q2.score, q3.score, fill_color="#E08E79", line_color="black")
p.vbar(cats, 0.7, q1.score, q2.score, fill_color="#3B8686", line_color="black")

# whiskers (almost-0 height rects simpler than segments)
p.rect(cats, lower.score, 0.2, 0.01, line_color="black")
p.rect(cats, upper.score, 0.2, 0.01, line_color="black")

# outliers
if not out.empty:
    p.circle(outx, outy, size=6, color="#F38630", fill_alpha=0.6)

p.xgrid.grid_line_color = None
p.ygrid.grid_line_color = "white"
p.grid.grid_line_width = 2
p.xaxis.major_label_text_font_size="12pt"

output_file("boxplot.html", title="boxplot.py example")

show(p)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-79-829e63669d5d> in <module>
# ----> 1 from bokeh.plotting import figure, show, output_file
#       2
#       3 # generate some synthetic time series for six different categories
#       4 cats = list("abcdef")
#       5 yy = np.random.randn(2000)
#
# ModuleNotFoundError: No module named 'bokeh'

# %%
sklearn
# Out:
# <module 'sklearn' from 'd:\\software\\python36\\lib\\site-packages\\sklearn\\__init__.py'>
